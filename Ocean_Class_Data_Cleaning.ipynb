# %% [markdown]
# <a href="https://colab.research.google.com/github/snehasri2600/Ocean-Classification/blob/main/Ocean_Class_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# # Data Description
#
# [ArcGIS Map Layer for Classification:](https://data-gis.unep-wcmc.org/portal/home/item.html?id=80567b4443f4457b822f645a2f0d70cf)
# This map layer provides a regional classification system for ocean water by realm and biome, depending on the column. Combines 2 datasets in itself -- one from 2007 (MEOW), the other from 2012 (PPOW). Type: shapefile with polygon geometries.
#
# [ECCO Datasets with Ocean Measurements:](https://podaac.jpl.nasa.gov/ECCO?sections=data)
# This is a series of datasets provided by NASA with daily and monthly means of different variables. Features will be selected from this dataset to classify ocean realms. For this project, I will use the latest available monthly mean data (December 2017), though one consideration is summer/winter seasons in different hemispheres. A complete time series analysis would be required for more definitive results. Type: netCDF files with latitude, longitude, and time.
#
# Variables:
# *   [Atmospheric surface temperature, humidity, wind, and pressure](https://podaac.jpl.nasa.gov/dataset/ECCO_L4_ATM_STATE_05DEG_MONTHLY_V4R4)
# *   [Ocean density, stratification, and hydrostatic pressure](https://podaac.jpl.nasa.gov/dataset/ECCO_L4_DENS_STRAT_PRESS_05DEG_DAILY_V4R4)
# * If needed: [Ocean temperature and salinity](https://podaac.jpl.nasa.gov/dataset/ECCO_L4_TEMP_SALINITY_05DEG_DAILY_V4R4) (this data is only available as a daily mean, but data is available as individual files for each date in December 2017. Monthly means can be calculated and added to this analysis if needed.)

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gdown

# %%
# !pip install arcgis
# Out:
# Requirement already satisfied: arcgis in /usr/local/lib/python3.12/dist-packages (2.4.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from arcgis) (11.3.0)
# Requirement already satisfied: urllib3<3,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (2.5.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from arcgis) (6.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from arcgis) (6.0.2)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from arcgis) (43.0.3)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (2.2.2)
# Requirement already satisfied: numpy<3,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (2.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from arcgis) (3.10.0)
# Requirement already satisfied: keyring>=23.3.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (25.7.0)
# Requirement already satisfied: pylerc in /usr/local/lib/python3.12/dist-packages (from arcgis) (4.0)
# Requirement already satisfied: ujson>=3 in /usr/local/lib/python3.12/dist-packages (from arcgis) (5.11.0)
# Requirement already satisfied: truststore>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (0.10.4)
# Requirement already satisfied: geomet>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (1.1.0)
# Requirement already satisfied: requests<3,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from arcgis) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from arcgis) (2.0.0)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from arcgis) (1.0.0)
# Requirement already satisfied: pyspnego>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from arcgis) (0.12.0)
# Requirement already satisfied: dask<2025.3,>=2024.12.1 in /usr/local/lib/python3.12/dist-packages (from dask[dataframe]<2025.3,>=2024.12.1->arcgis) (2025.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from arcgis) (0.2.1)
# Requirement already satisfied: pyarrow<21,>=17 in /usr/local/lib/python3.12/dist-packages (from arcgis) (18.1.0)
# Requirement already satisfied: puremagic<2,>=1.15 in /usr/local/lib/python3.12/dist-packages (from arcgis) (1.30)
# Requirement already satisfied: pydantic<3,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from arcgis) (2.12.3)
# Requirement already satisfied: networkx<4,>=3.3 in /usr/local/lib/python3.12/dist-packages (from arcgis) (3.6)
# Requirement already satisfied: websocket-client<2.0.0,>=1.2.3 in /usr/local/lib/python3.12/dist-packages (from arcgis) (1.9.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (0.12.1)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=23.3.0->arcgis) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=23.3.0->arcgis) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=23.3.0->arcgis) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=23.3.0->arcgis) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=23.3.0->arcgis) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->arcgis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->arcgis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=2.0.0->arcgis) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.8.2->arcgis) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.8.2->arcgis) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.8.2->arcgis) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.8.2->arcgis) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.3->arcgis) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.3->arcgis) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.3->arcgis) (2025.11.12)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->arcgis) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arcgis) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arcgis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arcgis) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arcgis) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->arcgis) (3.2.5)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from matplotlib-inline->arcgis) (5.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->arcgis) (3.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->arcgis) (2.23)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask<2025.3,>=2024.12.1->dask[dataframe]<2025.3,>=2024.12.1->arcgis) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=2.0.0->arcgis) (1.17.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=23.3.0->arcgis) (10.8.0)

# %% [markdown]
# # Downloading and Exploring the Classification Layer

# %%
import arcgis

# %%
from arcgis import GIS
from arcgis.features import FeatureLayer, FeatureLayerCollection

# %%
gis = GIS()
class_layer_to_query = FeatureLayer('https://data-gis.unep-wcmc.org/server/rest/services/WCMC036_MEOW_PPOW_2007_2012/MapServer/0')

# %%
class_layer = class_layer_to_query.query(where='1=1', out_fields='REALM', geometry_precision=2, return_geometry=True)

# %%
# Exlporing the classificiation map shapefile dataset
import geopandas as gpd

# %%
classification = gpd.read_file(class_layer)
# Out:
# /usr/local/lib/python3.12/dist-packages/pyogrio/raw.py:198: RuntimeWarning: organizePolygons() received a polygon with more than 100 parts. The processing may be really slow.  You can skip the processing by setting METHOD=SKIP, or only make it analyze counter-clock wise parts by setting METHOD=ONLY_CCW if you can assume that the outline of holes is counter-clock wise defined
#   return ogr_read(

# %%
# Check coordinate system of GeoDataFrame
print(classification.crs)
# Out:
# EPSG:4326

# %%
# Display the the GeoDataFrame
display(classification)
# Out:
#      objectid                    realm  \
# 0           1  Indo-Pacific Warm Water
# 1           2      Southern Cold Water
# 2           3      Southern Cold Water
# 3           4      Northern Cold Water
# 4           5      Atlantic Warm Water
# ..        ...                      ...
# 264       265    Temperate Australasia
# 265       266    Temperate Australasia
# 266       267    Temperate Australasia
# 267       268    Temperate Australasia
# 268       269           Southern Ocean
#
#                                               geometry
# 0    POLYGON ((43.39 -16.53, 43.39 -16.53, 43.39 -1...
# 1    MULTIPOLYGON (((46.59 -52.16, 46.69 -52.18, 46...
# 2    POLYGON ((55.95 -45.5, 56.05 -45.51, 56.15 -45...
# 3    MULTIPOLYGON (((180 84.3, 180 84.2, 180 84.1, ...
# 4    POLYGON ((11.61 -15.78, 11.61 -15.79, 11.61 -1...
# ..                                                 ...
# 264  MULTIPOLYGON (((-177.78 -29.23, -177.77 -29.24...
# 265  MULTIPOLYGON (((173.24 -34.41, 173.24 -34.41, ...
# 266  POLYGON ((-176.29 -43.35, -176.28 -43.35, -176...
# 267  MULTIPOLYGON (((172.73 -34.53, 172.73 -34.53, ...
# 268  MULTIPOLYGON (((178.99 -47.31, 179.01 -47.31, ...
#
# [269 rows x 3 columns]

# %%
print(classification['realm'].unique())
# Out:
# ['Indo-Pacific Warm Water' 'Southern Cold Water' 'Northern Cold Water'
#  'Atlantic Warm Water' 'Arctic' 'Temperate Northern Atlantic'
#  'Temperate Northern Pacific' 'Tropical Atlantic' 'Western Indo-Pacific'
#  'Central Indo-Pacific' 'Eastern Indo-Pacific' 'Tropical Eastern Pacific'
#  'Temperate South America' 'Temperate Southern Africa'
#  'Temperate Australasia' 'Southern Ocean']

# %%
classification.plot(column='realm', legend=True, legend_kwds={'loc': 'right', 'bbox_to_anchor':(1.6,0.5)})
plt.show()

# %% [markdown]
# # Converting the Features (Variables) to a DataFrame

# %%
import xarray as xr

#Atmpospheric surface temperature, humidity, wind speed, and pressure
# Use gdown to download the file directly from Google Drive
atm_id = '1tBkiAVTMh3U8Dqx8um4jctk6YoZFt_dt'
atm_output = 'atm_temp_wind_hum_pres.nc'
gdown.download(id=atm_id, output=atm_output, quiet=False)

# !pip install netcdf4 # Install netcdf4 for xarray to use
atm_variables = xr.open_dataset(atm_output)
display(atm_variables)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tBkiAVTMh3U8Dqx8um4jctk6YoZFt_dt
# To: /content/atm_temp_wind_hum_pres.nc
# 100%|██████████| 1.81M/1.81M [00:00<00:00, 90.4MB/s]
# Collecting netcdf4
#   Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting cftime (from netcdf4)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4) (2025.11.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netcdf4) (2.3.5)
# Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 64.3 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.4 MB/s eta 0:00:00
# Installing collected packages: cftime, netcdf4
# Successfully installed cftime-1.6.5 netcdf4-1.7.3
# <xarray.Dataset> Size: 6MB
# Dimensions:         (time: 1, latitude: 360, longitude: 720, nv: 2)
# Coordinates:
#   * time            (time) datetime64[ns] 8B 2017-12-16T06:00:00
#   * latitude        (latitude) float32 1kB -89.75 -89.25 -88.75 ... 89.25 89.75
#   * longitude       (longitude) float32 3kB -179.8 -179.2 -178.8 ... 179.2 179.8
#     time_bnds       (time, nv) datetime64[ns] 16B ...
#     latitude_bnds   (latitude, nv) float32 3kB ...
#     longitude_bnds  (longitude, nv) float32 6kB ...
# Dimensions without coordinates: nv
# Data variables:
#     EXFatemp        (time, latitude, longitude) float32 1MB ...
#     EXFaqh          (time, latitude, longitude) float32 1MB ...
#     EXFewind        (time, latitude, longitude) float32 1MB ...
#     EXFnwind        (time, latitude, longitude) float32 1MB ...
#     EXFwspee        (time, latitude, longitude) float32 1MB ...
#     EXFpress        (time, latitude, longitude) float32 1MB ...
# Attributes: (12/57)
#     acknowledgement:              This research was carried out by the Jet Pr...
#     author:                       Ian Fenty and Ou Wang
#     cdm_data_type:                Grid
#     comment:                      Fields provided on a regular lat-lon grid. ...
#     Conventions:                  CF-1.8, ACDD-1.3
#     coordinates_comment:          Note: the global 'coordinates' attribute de...
#     ...                           ...
#     time_coverage_duration:       P1M
#     time_coverage_end:            2017-12-31T12:00:00
#     time_coverage_resolution:     P1M
#     time_coverage_start:          2017-12-01T00:00:00
#     title:                        ECCO Atmosphere Surface Temperature, Humidi...
#     uuid:                         a40f85ae-4158-11eb-a6e9-0cc47a3f8269

# %%
# Ocean density, stratification, and hydrostatic pressure
# Use gdown to download the file directly from Google Drive
file_id1 = '1xxHT73c3JeP2Ql0zF-lFHbkf9_4kWuqS'
output_file1 = 'density_strat_hydropres.nc'
gdown.download(id=file_id1, output=output_file1, quiet=False)

dens_strat_hydropres = xr.open_dataset(output_file1)
display(dens_strat_hydropres)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xxHT73c3JeP2Ql0zF-lFHbkf9_4kWuqS
# To: /content/density_strat_hydropres.nc
# 100%|██████████| 33.6M/33.6M [00:00<00:00, 73.8MB/s]
# <xarray.Dataset> Size: 156MB
# Dimensions:         (time: 1, Z: 50, latitude: 360, longitude: 720, nv: 2)
# Coordinates:
#   * time            (time) datetime64[ns] 8B 2017-12-16T06:00:00
#   * Z               (Z) float32 200B -5.0 -15.0 -25.0 ... -5.461e+03 -5.906e+03
#   * latitude        (latitude) float32 1kB -89.75 -89.25 -88.75 ... 89.25 89.75
#   * longitude       (longitude) float32 3kB -179.8 -179.2 -178.8 ... 179.2 179.8
#     time_bnds       (time, nv) datetime64[ns] 16B ...
#     latitude_bnds   (latitude, nv) float32 3kB ...
#     longitude_bnds  (longitude, nv) float32 6kB ...
#     Z_bnds          (Z, nv) float32 400B ...
# Dimensions without coordinates: nv
# Data variables:
#     RHOAnoma        (time, Z, latitude, longitude) float32 52MB ...
#     DRHODR          (time, Z, latitude, longitude) float32 52MB ...
#     PHIHYD          (time, Z, latitude, longitude) float32 52MB ...
# Attributes: (12/62)
#     acknowledgement:                 This research was carried out by the Jet...
#     author:                          Ian Fenty and Ou Wang
#     cdm_data_type:                   Grid
#     comment:                         Fields provided on a regular lat-lon gri...
#     Conventions:                     CF-1.8, ACDD-1.3
#     coordinates_comment:             Note: the global 'coordinates' attribute...
#     ...                              ...
#     time_coverage_duration:          P1M
#     time_coverage_end:               2017-12-31T12:00:00
#     time_coverage_resolution:        P1M
#     time_coverage_start:             2017-12-01T00:00:00
#     title:                           ECCO Ocean Density, Stratification, and ...
#     uuid:                            109d84b8-415a-11eb-b774-0cc47a3f69ef

# %%
#Merging the datasets
all_variables = xr.merge([atm_variables, dens_strat_hydropres])
display(all_variables)
# Out:
# /tmp/ipython-input-2328718939.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   all_variables = xr.merge([atm_variables, dens_strat_hydropres])
# /tmp/ipython-input-2328718939.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   all_variables = xr.merge([atm_variables, dens_strat_hydropres])
# /tmp/ipython-input-2328718939.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   all_variables = xr.merge([atm_variables, dens_strat_hydropres])
# <xarray.Dataset> Size: 162MB
# Dimensions:         (time: 1, latitude: 360, longitude: 720, nv: 2, Z: 50)
# Coordinates:
#   * time            (time) datetime64[ns] 8B 2017-12-16T06:00:00
#   * latitude        (latitude) float32 1kB -89.75 -89.25 -88.75 ... 89.25 89.75
#   * longitude       (longitude) float32 3kB -179.8 -179.2 -178.8 ... 179.2 179.8
#   * Z               (Z) float32 200B -5.0 -15.0 -25.0 ... -5.461e+03 -5.906e+03
#     time_bnds       (time, nv) datetime64[ns] 16B 2017-12-01 2017-12-31T12:00:00
#     latitude_bnds   (latitude, nv) float32 3kB -90.0 -89.5 -89.5 ... 89.5 90.0
#     longitude_bnds  (longitude, nv) float32 6kB -180.0 -179.5 ... 179.5 180.0
#     Z_bnds          (Z, nv) float32 400B ...
# Dimensions without coordinates: nv
# Data variables:
#     EXFatemp        (time, latitude, longitude) float32 1MB ...
#     EXFaqh          (time, latitude, longitude) float32 1MB ...
#     EXFewind        (time, latitude, longitude) float32 1MB ...
#     EXFnwind        (time, latitude, longitude) float32 1MB ...
#     EXFwspee        (time, latitude, longitude) float32 1MB ...
#     EXFpress        (time, latitude, longitude) float32 1MB ...
#     RHOAnoma        (time, Z, latitude, longitude) float32 52MB ...
#     DRHODR          (time, Z, latitude, longitude) float32 52MB ...
#     PHIHYD          (time, Z, latitude, longitude) float32 52MB ...
# Attributes: (12/57)
#     acknowledgement:              This research was carried out by the Jet Pr...
#     author:                       Ian Fenty and Ou Wang
#     cdm_data_type:                Grid
#     comment:                      Fields provided on a regular lat-lon grid. ...
#     Conventions:                  CF-1.8, ACDD-1.3
#     coordinates_comment:          Note: the global 'coordinates' attribute de...
#     ...                           ...
#     time_coverage_duration:       P1M
#     time_coverage_end:            2017-12-31T12:00:00
#     time_coverage_resolution:     P1M
#     time_coverage_start:          2017-12-01T00:00:00
#     title:                        ECCO Atmosphere Surface Temperature, Humidi...
#     uuid:                         a40f85ae-4158-11eb-a6e9-0cc47a3f8269

# %%
#Converting to DataFrame and unstacking the MultiIndex layers
all_variables_df = all_variables[['EXFatemp', 'EXFaqh','EXFewind','EXFnwind','EXFwspee','EXFpress','RHOAnoma','DRHODR','PHIHYD']].to_dataframe(dim_order = ['time', 'latitude','longitude','Z']).reset_index()
print(all_variables_df.columns)
display(all_variables_df)
# Out:
# Index(['time', 'latitude', 'longitude', 'Z', 'EXFatemp', 'EXFaqh', 'EXFewind',
#        'EXFnwind', 'EXFwspee', 'EXFpress', 'RHOAnoma', 'DRHODR', 'PHIHYD'],
#       dtype='object')
#                         time  latitude  longitude        Z    EXFatemp  \
# 0        2017-12-16 06:00:00    -89.75    -179.75    -5.00         NaN
# 1        2017-12-16 06:00:00    -89.75    -179.75   -15.00         NaN
# 2        2017-12-16 06:00:00    -89.75    -179.75   -25.00         NaN
# 3        2017-12-16 06:00:00    -89.75    -179.75   -35.00         NaN
# 4        2017-12-16 06:00:00    -89.75    -179.75   -45.00         NaN
# ...                      ...       ...        ...      ...         ...
# 12959995 2017-12-16 06:00:00     89.75     179.75 -4264.25  253.645111
# 12959996 2017-12-16 06:00:00     89.75     179.75 -4640.25  253.645111
# 12959997 2017-12-16 06:00:00     89.75     179.75 -5039.25  253.645111
# 12959998 2017-12-16 06:00:00     89.75     179.75 -5461.25  253.645111
# 12959999 2017-12-16 06:00:00     89.75     179.75 -5906.25  253.645111
#
#             EXFaqh  EXFewind  EXFnwind  EXFwspee       EXFpress   RHOAnoma  \
# 0              NaN       NaN       NaN       NaN            NaN        NaN
# 1              NaN       NaN       NaN       NaN            NaN        NaN
# 2              NaN       NaN       NaN       NaN            NaN        NaN
# 3              NaN       NaN       NaN       NaN            NaN        NaN
# 4              NaN       NaN       NaN       NaN            NaN        NaN
# ...            ...       ...       ...       ...            ...        ...
# 12959995  0.000698  5.007825  2.929656  7.353284  102142.109375  18.748615
# 12959996  0.000698  5.007825  2.929656  7.353284  102142.109375        NaN
# 12959997  0.000698  5.007825  2.929656  7.353284  102142.109375        NaN
# 12959998  0.000698  5.007825  2.929656  7.353284  102142.109375        NaN
# 12959999  0.000698  5.007825  2.929656  7.353284  102142.109375        NaN
#
#             DRHODR      PHIHYD
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 12959995 -0.000002  458.823883
# 12959996       NaN         NaN
# 12959997       NaN         NaN
# 12959998       NaN         NaN
# 12959999       NaN         NaN
#
# [12960000 rows x 13 columns]

# %% [markdown]
# # Fitting Features into the Classification File

# %%
print(all_variables_df['Z'].unique())
print(all_variables_df['Z'].min())
print(all_variables_df['Z'].max())

# # # Since many of our variables are atmosphere-related, a low depth could be useful for this model. We will filter the data so we only have data that is measured at a -5.0ft depth.
all_variables_df = all_variables_df[all_variables_df['Z'] == -5.0]

# # # We can now safely drop the depth variable from our dataset
all_variables_df = all_variables_df.drop(['Z'], axis=1)
display(all_variables_df)
# Out:
# [-5.000000e+00 -1.500000e+01 -2.500000e+01 -3.500000e+01 -4.500000e+01
#  -5.500000e+01 -6.500000e+01 -7.500500e+01 -8.502500e+01 -9.509500e+01
#  -1.053100e+02 -1.158700e+02 -1.271500e+02 -1.397400e+02 -1.544700e+02
#  -1.724000e+02 -1.947350e+02 -2.227100e+02 -2.574700e+02 -2.999300e+02
#  -3.506800e+02 -4.099300e+02 -4.774700e+02 -5.527100e+02 -6.347350e+02
#  -7.224000e+02 -8.144700e+02 -9.097400e+02 -1.007155e+03 -1.105905e+03
#  -1.205535e+03 -1.306205e+03 -1.409150e+03 -1.517095e+03 -1.634175e+03
#  -1.765135e+03 -1.914150e+03 -2.084035e+03 -2.276225e+03 -2.491250e+03
#  -2.729250e+03 -2.990250e+03 -3.274250e+03 -3.581250e+03 -3.911250e+03
#  -4.264250e+03 -4.640250e+03 -5.039250e+03 -5.461250e+03 -5.906250e+03]
# -5906.25
# -5.0
#                         time  latitude  longitude    EXFatemp    EXFaqh  \
# 0        2017-12-16 06:00:00    -89.75    -179.75         NaN       NaN
# 50       2017-12-16 06:00:00    -89.75    -179.25         NaN       NaN
# 100      2017-12-16 06:00:00    -89.75    -178.75         NaN       NaN
# 150      2017-12-16 06:00:00    -89.75    -178.25         NaN       NaN
# 200      2017-12-16 06:00:00    -89.75    -177.75         NaN       NaN
# ...                      ...       ...        ...         ...       ...
# 12959750 2017-12-16 06:00:00     89.75     177.75  253.645111  0.000698
# 12959800 2017-12-16 06:00:00     89.75     178.25  253.645111  0.000698
# 12959850 2017-12-16 06:00:00     89.75     178.75  253.645111  0.000698
# 12959900 2017-12-16 06:00:00     89.75     179.25  253.645111  0.000698
# 12959950 2017-12-16 06:00:00     89.75     179.75  253.645111  0.000698
#
#           EXFewind  EXFnwind  EXFwspee       EXFpress  RHOAnoma  DRHODR  \
# 0              NaN       NaN       NaN            NaN       NaN     NaN
# 50             NaN       NaN       NaN            NaN       NaN     NaN
# 100            NaN       NaN       NaN            NaN       NaN     NaN
# 150            NaN       NaN       NaN            NaN       NaN     NaN
# 200            NaN       NaN       NaN            NaN       NaN     NaN
# ...            ...       ...       ...            ...       ...     ...
# 12959750  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959800  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959850  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959900  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959950  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
#
#               PHIHYD
# 0                NaN
# 50               NaN
# 100              NaN
# 150              NaN
# 200              NaN
# ...              ...
# 12959750  109.382149
# 12959800  109.382149
# 12959850  109.382149
# 12959900  109.382149
# 12959950  109.382149
#
# [259200 rows x 12 columns]

# %%
print(classification['geometry'].unique)
# Out:
# <bound method Series.unique of 0      POLYGON ((43.39 -16.53, 43.39 -16.53, 43.39 -1...
# 1      MULTIPOLYGON (((46.59 -52.16, 46.69 -52.18, 46...
# 2      POLYGON ((55.95 -45.5, 56.05 -45.51, 56.15 -45...
# 3      MULTIPOLYGON (((180 84.3, 180 84.2, 180 84.1, ...
# 4      POLYGON ((11.61 -15.78, 11.61 -15.79, 11.61 -1...
#                              ...
# 264    MULTIPOLYGON (((-177.78 -29.23, -177.77 -29.24...
# 265    MULTIPOLYGON (((173.24 -34.41, 173.24 -34.41, ...
# 266    POLYGON ((-176.29 -43.35, -176.28 -43.35, -176...
# 267    MULTIPOLYGON (((172.73 -34.53, 172.73 -34.53, ...
# 268    MULTIPOLYGON (((178.99 -47.31, 179.01 -47.31, ...
# Name: geometry, Length: 269, dtype: geometry>

# %% [markdown]
# Because the classification dataset has polygons and multipolygons as its geometry, I need to use GeoPandas to conduct a spatial join of the two datasets.

# %%
# Creating a geometry column with latitude and longitude values according to a specific coordinate system within all_variables
variable_geometry = gpd.points_from_xy(all_variables_df['latitude'], all_variables_df['longitude'])

# Turning all_variables into a GeoDataFrame in order to merge with the classification dataset (this takes the latitude and longitude columns and turns them into point geometry)
all_variables_gdf = gpd.GeoDataFrame(all_variables_df, geometry=variable_geometry, crs='EPSG:4326')
display(all_variables_gdf)
# Out:
#                         time  latitude  longitude    EXFatemp    EXFaqh  \
# 0        2017-12-16 06:00:00    -89.75    -179.75         NaN       NaN
# 50       2017-12-16 06:00:00    -89.75    -179.25         NaN       NaN
# 100      2017-12-16 06:00:00    -89.75    -178.75         NaN       NaN
# 150      2017-12-16 06:00:00    -89.75    -178.25         NaN       NaN
# 200      2017-12-16 06:00:00    -89.75    -177.75         NaN       NaN
# ...                      ...       ...        ...         ...       ...
# 12959750 2017-12-16 06:00:00     89.75     177.75  253.645111  0.000698
# 12959800 2017-12-16 06:00:00     89.75     178.25  253.645111  0.000698
# 12959850 2017-12-16 06:00:00     89.75     178.75  253.645111  0.000698
# 12959900 2017-12-16 06:00:00     89.75     179.25  253.645111  0.000698
# 12959950 2017-12-16 06:00:00     89.75     179.75  253.645111  0.000698
#
#           EXFewind  EXFnwind  EXFwspee       EXFpress  RHOAnoma  DRHODR  \
# 0              NaN       NaN       NaN            NaN       NaN     NaN
# 50             NaN       NaN       NaN            NaN       NaN     NaN
# 100            NaN       NaN       NaN            NaN       NaN     NaN
# 150            NaN       NaN       NaN            NaN       NaN     NaN
# 200            NaN       NaN       NaN            NaN       NaN     NaN
# ...            ...       ...       ...            ...       ...     ...
# 12959750  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959800  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959850  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959900  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
# 12959950  5.007825  2.929656  7.353284  102142.109375 -3.049556     0.0
#
#               PHIHYD                geometry
# 0                NaN  POINT (-89.75 -179.75)
# 50               NaN  POINT (-89.75 -179.25)
# 100              NaN  POINT (-89.75 -178.75)
# 150              NaN  POINT (-89.75 -178.25)
# 200              NaN  POINT (-89.75 -177.75)
# ...              ...                     ...
# 12959750  109.382149    POINT (89.75 177.75)
# 12959800  109.382149    POINT (89.75 178.25)
# 12959850  109.382149    POINT (89.75 178.75)
# 12959900  109.382149    POINT (89.75 179.25)
# 12959950  109.382149    POINT (89.75 179.75)
#
# [259200 rows x 13 columns]

# %%
#Merging all_variables_gdf with classification using a spatial join
merged_gdf = gpd.sjoin(all_variables_gdf, classification, how='inner', predicate='within')
display(merged_gdf)
# Out:
#                         time  latitude  longitude    EXFatemp    EXFaqh  \
# 10700    2017-12-16 06:00:00    -89.75     -72.75         NaN       NaN
# 10750    2017-12-16 06:00:00    -89.75     -72.25         NaN       NaN
# 10800    2017-12-16 06:00:00    -89.75     -71.75         NaN       NaN
# 10850    2017-12-16 06:00:00    -89.75     -71.25         NaN       NaN
# 10900    2017-12-16 06:00:00    -89.75     -70.75         NaN       NaN
# ...                      ...       ...        ...         ...       ...
# 12950750 2017-12-16 06:00:00     89.75      87.75  253.907761  0.000719
# 12950800 2017-12-16 06:00:00     89.75      88.25  253.907761  0.000719
# 12950850 2017-12-16 06:00:00     89.75      88.75  253.907761  0.000719
# 12950900 2017-12-16 06:00:00     89.75      89.25  253.907761  0.000719
# 12950950 2017-12-16 06:00:00     89.75      89.75  253.907761  0.000719
#
#           EXFewind  EXFnwind  EXFwspee       EXFpress  RHOAnoma  DRHODR  \
# 10700          NaN       NaN       NaN            NaN       NaN     NaN
# 10750          NaN       NaN       NaN            NaN       NaN     NaN
# 10800          NaN       NaN       NaN            NaN       NaN     NaN
# 10850          NaN       NaN       NaN            NaN       NaN     NaN
# 10900          NaN       NaN       NaN            NaN       NaN     NaN
# ...            ...       ...       ...            ...       ...     ...
# 12950750 -3.107174  4.886118  7.411502  102083.304688 -3.039971     0.0
# 12950800 -3.107174  4.886118  7.411502  102083.304688 -3.039971     0.0
# 12950850 -3.107174  4.886118  7.411502  102083.304688 -3.039971     0.0
# 12950900 -3.107174  4.886118  7.411502  102083.304688 -3.039971     0.0
# 12950950 -3.107174  4.886118  7.411502  102083.304688 -3.039971     0.0
#
#               PHIHYD               geometry  index_right  objectid  \
# 10700            NaN  POINT (-89.75 -72.75)          232       233
# 10750            NaN  POINT (-89.75 -72.25)          232       233
# 10800            NaN  POINT (-89.75 -71.75)            1         2
# 10850            NaN  POINT (-89.75 -71.25)            1         2
# 10900            NaN  POINT (-89.75 -70.75)            1         2
# ...              ...                    ...          ...       ...
# 12950750  109.265701    POINT (89.75 87.75)            3         4
# 12950800  109.265701    POINT (89.75 88.25)            3         4
# 12950850  109.265701    POINT (89.75 88.75)            3         4
# 12950900  109.265701    POINT (89.75 89.25)            3         4
# 12950950  109.265701    POINT (89.75 89.75)            3         4
#
#                         realm
# 10700          Southern Ocean
# 10750          Southern Ocean
# 10800     Southern Cold Water
# 10850     Southern Cold Water
# 10900     Southern Cold Water
# ...                       ...
# 12950750  Northern Cold Water
# 12950800  Northern Cold Water
# 12950850  Northern Cold Water
# 12950900  Northern Cold Water
# 12950950  Northern Cold Water
#
# [78830 rows x 16 columns]

# %%
#Renaming columns so they are more descriptive and understandable
merged_gdf.rename(columns={'EXFatemp':'atm_surface_temp', 'EXFaqh':'atm_surface_humidity', 'EXFewind':'zonal_wind_speed', 'EXFnwind':'meridional_wind_speed', 'EXFwspee':'wind_speed','EXFpress':'atm_surface_pressure', 'Z':'depth'}, inplace=True)
merged_gdf.rename(columns={'RHOAnoma':'seawater_density_anomaly', 'DRHODR':'density_stratification', 'PHIHYD':'hydrostatic_pressure_anomaly'}, inplace=True)
merged_gdf.rename(columns={'REALM':'realm'}, inplace=True)
display(merged_gdf)
# Out:
#                         time  latitude  longitude  atm_surface_temp  \
# 10700    2017-12-16 06:00:00    -89.75     -72.75               NaN
# 10750    2017-12-16 06:00:00    -89.75     -72.25               NaN
# 10800    2017-12-16 06:00:00    -89.75     -71.75               NaN
# 10850    2017-12-16 06:00:00    -89.75     -71.25               NaN
# 10900    2017-12-16 06:00:00    -89.75     -70.75               NaN
# ...                      ...       ...        ...               ...
# 12950750 2017-12-16 06:00:00     89.75      87.75        253.907761
# 12950800 2017-12-16 06:00:00     89.75      88.25        253.907761
# 12950850 2017-12-16 06:00:00     89.75      88.75        253.907761
# 12950900 2017-12-16 06:00:00     89.75      89.25        253.907761
# 12950950 2017-12-16 06:00:00     89.75      89.75        253.907761
#
#           atm_surface_humidity  zonal_wind_speed  meridional_wind_speed  \
# 10700                      NaN               NaN                    NaN
# 10750                      NaN               NaN                    NaN
# 10800                      NaN               NaN                    NaN
# 10850                      NaN               NaN                    NaN
# 10900                      NaN               NaN                    NaN
# ...                        ...               ...                    ...
# 12950750              0.000719         -3.107174               4.886118
# 12950800              0.000719         -3.107174               4.886118
# 12950850              0.000719         -3.107174               4.886118
# 12950900              0.000719         -3.107174               4.886118
# 12950950              0.000719         -3.107174               4.886118
#
#           wind_speed  atm_surface_pressure  seawater_density_anomaly  \
# 10700            NaN                   NaN                       NaN
# 10750            NaN                   NaN                       NaN
# 10800            NaN                   NaN                       NaN
# 10850            NaN                   NaN                       NaN
# 10900            NaN                   NaN                       NaN
# ...              ...                   ...                       ...
# 12950750    7.411502         102083.304688                 -3.039971
# 12950800    7.411502         102083.304688                 -3.039971
# 12950850    7.411502         102083.304688                 -3.039971
# 12950900    7.411502         102083.304688                 -3.039971
# 12950950    7.411502         102083.304688                 -3.039971
#
#           density_stratification  hydrostatic_pressure_anomaly  \
# 10700                        NaN                           NaN
# 10750                        NaN                           NaN
# 10800                        NaN                           NaN
# 10850                        NaN                           NaN
# 10900                        NaN                           NaN
# ...                          ...                           ...
# 12950750                     0.0                    109.265701
# 12950800                     0.0                    109.265701
# 12950850                     0.0                    109.265701
# 12950900                     0.0                    109.265701
# 12950950                     0.0                    109.265701
#
#                        geometry  index_right  objectid                realm
# 10700     POINT (-89.75 -72.75)          232       233       Southern Ocean
# 10750     POINT (-89.75 -72.25)          232       233       Southern Ocean
# 10800     POINT (-89.75 -71.75)            1         2  Southern Cold Water
# 10850     POINT (-89.75 -71.25)            1         2  Southern Cold Water
# 10900     POINT (-89.75 -70.75)            1         2  Southern Cold Water
# ...                         ...          ...       ...                  ...
# 12950750    POINT (89.75 87.75)            3         4  Northern Cold Water
# 12950800    POINT (89.75 88.25)            3         4  Northern Cold Water
# 12950850    POINT (89.75 88.75)            3         4  Northern Cold Water
# 12950900    POINT (89.75 89.25)            3         4  Northern Cold Water
# 12950950    POINT (89.75 89.75)            3         4  Northern Cold Water
#
# [78830 rows x 16 columns]

# %%
# Making sure nothing is misunderstood from the dataset
print(merged_gdf['time'].unique())
# Out:
# <DatetimeArray>
# ['2017-12-16 06:00:00']
# Length: 1, dtype: datetime64[ns]

# %% [markdown]
# There is only one datetime value across the board for all data, so that "variable" is obsolete (as expected).
#
# Additionally, certain variables cannot be used to build a machine learning model. For example, using latitude, longitude, or geometry would make the model obsolete, since the ocean has been specifically classified by location.

# %%
# Converting to a regular DataFrame
merged_df = pd.DataFrame(merged_gdf)
display(merged_df)
# Out:
#                         time  latitude  longitude  atm_surface_temp  \
# 10700    2017-12-16 06:00:00    -89.75     -72.75               NaN
# 10750    2017-12-16 06:00:00    -89.75     -72.25               NaN
# 10800    2017-12-16 06:00:00    -89.75     -71.75               NaN
# 10850    2017-12-16 06:00:00    -89.75     -71.25               NaN
# 10900    2017-12-16 06:00:00    -89.75     -70.75               NaN
# ...                      ...       ...        ...               ...
# 12950750 2017-12-16 06:00:00     89.75      87.75        253.907761
# 12950800 2017-12-16 06:00:00     89.75      88.25        253.907761
# 12950850 2017-12-16 06:00:00     89.75      88.75        253.907761
# 12950900 2017-12-16 06:00:00     89.75      89.25        253.907761
# 12950950 2017-12-16 06:00:00     89.75      89.75        253.907761
#
#           atm_surface_humidity  zonal_wind_speed  meridional_wind_speed  \
# 10700                      NaN               NaN                    NaN
# 10750                      NaN               NaN                    NaN
# 10800                      NaN               NaN                    NaN
# 10850                      NaN               NaN                    NaN
# 10900                      NaN               NaN                    NaN
# ...                        ...               ...                    ...
# 12950750              0.000719         -3.107174               4.886118
# 12950800              0.000719         -3.107174               4.886118
# 12950850              0.000719         -3.107174               4.886118
# 12950900              0.000719         -3.107174               4.886118
# 12950950              0.000719         -3.107174               4.886118
#
#           wind_speed  atm_surface_pressure  seawater_density_anomaly  \
# 10700            NaN                   NaN                       NaN
# 10750            NaN                   NaN                       NaN
# 10800            NaN                   NaN                       NaN
# 10850            NaN                   NaN                       NaN
# 10900            NaN                   NaN                       NaN
# ...              ...                   ...                       ...
# 12950750    7.411502         102083.304688                 -3.039971
# 12950800    7.411502         102083.304688                 -3.039971
# 12950850    7.411502         102083.304688                 -3.039971
# 12950900    7.411502         102083.304688                 -3.039971
# 12950950    7.411502         102083.304688                 -3.039971
#
#           density_stratification  hydrostatic_pressure_anomaly  \
# 10700                        NaN                           NaN
# 10750                        NaN                           NaN
# 10800                        NaN                           NaN
# 10850                        NaN                           NaN
# 10900                        NaN                           NaN
# ...                          ...                           ...
# 12950750                     0.0                    109.265701
# 12950800                     0.0                    109.265701
# 12950850                     0.0                    109.265701
# 12950900                     0.0                    109.265701
# 12950950                     0.0                    109.265701
#
#                        geometry  index_right  objectid                realm
# 10700     POINT (-89.75 -72.75)          232       233       Southern Ocean
# 10750     POINT (-89.75 -72.25)          232       233       Southern Ocean
# 10800     POINT (-89.75 -71.75)            1         2  Southern Cold Water
# 10850     POINT (-89.75 -71.25)            1         2  Southern Cold Water
# 10900     POINT (-89.75 -70.75)            1         2  Southern Cold Water
# ...                         ...          ...       ...                  ...
# 12950750    POINT (89.75 87.75)            3         4  Northern Cold Water
# 12950800    POINT (89.75 88.25)            3         4  Northern Cold Water
# 12950850    POINT (89.75 88.75)            3         4  Northern Cold Water
# 12950900    POINT (89.75 89.25)            3         4  Northern Cold Water
# 12950950    POINT (89.75 89.75)            3         4  Northern Cold Water
#
# [78830 rows x 16 columns]

# %%
# Drop time, latitude, longitude, and geometry columns
merged_df = merged_df.drop(['time', 'latitude', 'longitude', 'geometry'], axis=1, errors='ignore')

# Dropping categorical variables we don't want
merged_df = merged_df.drop(['index_right', 'globalid', 'objectid'], axis=1, errors='ignore')

# Dropping density stratification variable because we are only using one depth value
merged_df = merged_df.drop(['density_stratification'], axis=1, errors='ignore')

display(merged_df)
# Out:
#           atm_surface_temp  atm_surface_humidity  zonal_wind_speed  \
# 10700                  NaN                   NaN               NaN
# 10750                  NaN                   NaN               NaN
# 10800                  NaN                   NaN               NaN
# 10850                  NaN                   NaN               NaN
# 10900                  NaN                   NaN               NaN
# ...                    ...                   ...               ...
# 12950750        253.907761              0.000719         -3.107174
# 12950800        253.907761              0.000719         -3.107174
# 12950850        253.907761              0.000719         -3.107174
# 12950900        253.907761              0.000719         -3.107174
# 12950950        253.907761              0.000719         -3.107174
#
#           meridional_wind_speed  wind_speed  atm_surface_pressure  \
# 10700                       NaN         NaN                   NaN
# 10750                       NaN         NaN                   NaN
# 10800                       NaN         NaN                   NaN
# 10850                       NaN         NaN                   NaN
# 10900                       NaN         NaN                   NaN
# ...                         ...         ...                   ...
# 12950750               4.886118    7.411502         102083.304688
# 12950800               4.886118    7.411502         102083.304688
# 12950850               4.886118    7.411502         102083.304688
# 12950900               4.886118    7.411502         102083.304688
# 12950950               4.886118    7.411502         102083.304688
#
#           seawater_density_anomaly  hydrostatic_pressure_anomaly  \
# 10700                          NaN                           NaN
# 10750                          NaN                           NaN
# 10800                          NaN                           NaN
# 10850                          NaN                           NaN
# 10900                          NaN                           NaN
# ...                            ...                           ...
# 12950750                 -3.039971                    109.265701
# 12950800                 -3.039971                    109.265701
# 12950850                 -3.039971                    109.265701
# 12950900                 -3.039971                    109.265701
# 12950950                 -3.039971                    109.265701
#
#                         realm
# 10700          Southern Ocean
# 10750          Southern Ocean
# 10800     Southern Cold Water
# 10850     Southern Cold Water
# 10900     Southern Cold Water
# ...                       ...
# 12950750  Northern Cold Water
# 12950800  Northern Cold Water
# 12950850  Northern Cold Water
# 12950900  Northern Cold Water
# 12950950  Northern Cold Water
#
# [78830 rows x 9 columns]

# %% [markdown]
# Because the size of the dataset is large enough, we can drop missing values for dataset management purposes.

# %%
# Checking number of NaN values
print('NaN values in each column:')
print(merged_df.isna().sum())
# Out:
# NaN values in each column:
# atm_surface_temp                26884
# atm_surface_humidity            26884
# zonal_wind_speed                26884
# meridional_wind_speed           26884
# wind_speed                      26884
# atm_surface_pressure            26884
# seawater_density_anomaly        26884
# hydrostatic_pressure_anomaly    26884
# realm                               0
# dtype: int64

# %%
# Finding where the missing values are located
missing_values = merged_df[merged_df.isna().any(axis=1)]
display(missing_values)
# Out:
#           atm_surface_temp  atm_surface_humidity  zonal_wind_speed  \
# 10700                  NaN                   NaN               NaN
# 10750                  NaN                   NaN               NaN
# 10800                  NaN                   NaN               NaN
# 10850                  NaN                   NaN               NaN
# 10900                  NaN                   NaN               NaN
# ...                    ...                   ...               ...
# 12471150               NaN                   NaN               NaN
# 12471200               NaN                   NaN               NaN
# 12471250               NaN                   NaN               NaN
# 12471300               NaN                   NaN               NaN
# 12471350               NaN                   NaN               NaN
#
#           meridional_wind_speed  wind_speed  atm_surface_pressure  \
# 10700                       NaN         NaN                   NaN
# 10750                       NaN         NaN                   NaN
# 10800                       NaN         NaN                   NaN
# 10850                       NaN         NaN                   NaN
# 10900                       NaN         NaN                   NaN
# ...                         ...         ...                   ...
# 12471150                    NaN         NaN                   NaN
# 12471200                    NaN         NaN                   NaN
# 12471250                    NaN         NaN                   NaN
# 12471300                    NaN         NaN                   NaN
# 12471350                    NaN         NaN                   NaN
#
#           seawater_density_anomaly  hydrostatic_pressure_anomaly  \
# 10700                          NaN                           NaN
# 10750                          NaN                           NaN
# 10800                          NaN                           NaN
# 10850                          NaN                           NaN
# 10900                          NaN                           NaN
# ...                            ...                           ...
# 12471150                       NaN                           NaN
# 12471200                       NaN                           NaN
# 12471250                       NaN                           NaN
# 12471300                       NaN                           NaN
# 12471350                       NaN                           NaN
#
#                             realm
# 10700              Southern Ocean
# 10750              Southern Ocean
# 10800         Southern Cold Water
# 10850         Southern Cold Water
# 10900         Southern Cold Water
# ...                           ...
# 12471150  Indo-Pacific Warm Water
# 12471200  Indo-Pacific Warm Water
# 12471250  Indo-Pacific Warm Water
# 12471300  Indo-Pacific Warm Water
# 12471350  Indo-Pacific Warm Water
#
# [26884 rows x 9 columns]

# %%
# Dropping the missing values
merged_df_cleaned = merged_df.dropna()
display(merged_df_cleaned)
# Out:
#           atm_surface_temp  atm_surface_humidity  zonal_wind_speed  \
# 877250          258.807037              0.002396         -1.421412
# 877300          258.807037              0.002396         -1.421412
# 877350          259.485046              0.002413         -1.475978
# 877400          259.485046              0.002413         -1.475978
# 877450          260.288879              0.002427         -1.533721
# ...                    ...                   ...               ...
# 12950750        253.907761              0.000719         -3.107174
# 12950800        253.907761              0.000719         -3.107174
# 12950850        253.907761              0.000719         -3.107174
# 12950900        253.907761              0.000719         -3.107174
# 12950950        253.907761              0.000719         -3.107174
#
#           meridional_wind_speed  wind_speed  atm_surface_pressure  \
# 877250                 1.504944    3.966997          98732.859375
# 877300                 1.504944    3.966997          98732.859375
# 877350                 1.528884    4.023276          98726.882812
# 877400                 1.528884    4.023276          98726.882812
# 877450                 1.645065    4.075678          98722.546875
# ...                         ...         ...                   ...
# 12950750               4.886118    7.411502         102083.304688
# 12950800               4.886118    7.411502         102083.304688
# 12950850               4.886118    7.411502         102083.304688
# 12950900               4.886118    7.411502         102083.304688
# 12950950               4.886118    7.411502         102083.304688
#
#           seawater_density_anomaly  hydrostatic_pressure_anomaly  \
# 877250                   -1.497837                    120.338600
# 877300                   -1.497837                    120.338600
# 877350                   -1.499950                    123.399620
# 877400                   -1.499950                    123.399620
# 877450                   -1.505903                    130.803513
# ...                            ...                           ...
# 12950750                 -3.039971                    109.265701
# 12950800                 -3.039971                    109.265701
# 12950850                 -3.039971                    109.265701
# 12950900                 -3.039971                    109.265701
# 12950950                 -3.039971                    109.265701
#
#                         realm
# 877250    Southern Cold Water
# 877300    Southern Cold Water
# 877350    Southern Cold Water
# 877400    Southern Cold Water
# 877450    Southern Cold Water
# ...                       ...
# 12950750  Northern Cold Water
# 12950800  Northern Cold Water
# 12950850  Northern Cold Water
# 12950900  Northern Cold Water
# 12950950  Northern Cold Water
#
# [51946 rows x 9 columns]

# %%
# Converting the cleaned dataframe to a downloadable CSV file for future use
merged_df_cleaned.to_csv('merged_df_cleaned.csv', index=False)

# %%
from google.colab import files
files.download('merged_df_cleaned.csv')

# %% [markdown]
# The final dataset is now a DataFrame with all necessary variables for machine learning. I can now import scikitlearn and begin data splitting and preprocessing for the model.

# %% [markdown]
# # Data Preprocessing

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
# Import libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
# Define features (X) and target (y)

# Dropping 'realm' from the features column so we can use all other variables as features, and label the target as the 'realm'
X = merged_df_cleaned.drop(['realm'], axis=1)
y = merged_df_cleaned['realm']

# Split into testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
# Exploring the training set
print(X_train.info())
print(X_train.describe())
print(y_train.info())
print(y_train.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38959 entries, 5634450 to 4338150
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   atm_surface_temp              38959 non-null  float32
#  1   atm_surface_humidity          38959 non-null  float32
#  2   zonal_wind_speed              38959 non-null  float32
#  3   meridional_wind_speed         38959 non-null  float32
#  4   wind_speed                    38959 non-null  float32
#  5   atm_surface_pressure          38959 non-null  float32
#  6   seawater_density_anomaly      38959 non-null  float32
#  7   hydrostatic_pressure_anomaly  38959 non-null  float32
# dtypes: float32(8)
# memory usage: 1.5 MB
# None
#        atm_surface_temp  atm_surface_humidity  zonal_wind_speed  \
# count      38959.000000          38959.000000      38959.000000
# mean         284.726440              0.008902          0.358125
# std           13.555584              0.005641          4.963863
# min          244.633942              0.000300         -8.781069
# 25%          274.778229              0.003593         -3.783217
# 50%          288.367157              0.008617         -0.067574
# 75%          297.019287              0.014079          4.426078
# max          301.631866              0.018931         11.012135
#
#        meridional_wind_speed    wind_speed  atm_surface_pressure  \
# count           38959.000000  38959.000000          38959.000000
# mean               -0.217578      7.693167         100844.906250
# std                 2.743976      2.104699           1173.036987
# min                -9.712660      1.846863          97453.117188
# 25%                -1.764890      6.237711         100496.347656
# 50%                -0.505339      7.481523         101178.343750
# 75%                 1.315369      9.356461         101602.453125
# max                 8.735123     12.808892         102887.023438
#
#        seawater_density_anomaly  hydrostatic_pressure_anomaly
# count              38959.000000                  38959.000000
# mean                  -3.593824                     99.082161
# std                    1.711745                      3.856571
# min                  -10.826721                     94.596924
# 25%                   -4.656486                     97.780891
# 50%                   -3.199425                     98.234657
# 75%                   -2.175089                     98.777588
# max                   -0.100794                    132.923767
# <class 'pandas.core.series.Series'>
# Index: 38959 entries, 5634450 to 4338150
# Series name: realm
# Non-Null Count  Dtype
# --------------  -----
# 38959 non-null  object
# dtypes: object(1)
# memory usage: 608.7+ KB
# None
# count                   38959
# unique                     11
# top       Atlantic Warm Water
# freq                    13156
# Name: realm, dtype: object

# %% [markdown]
# We can now use the OneHotEncoder on the target for this model.

# %%
ohe = OneHotEncoder(sparse_output=False)

# Reshape y_train and y_test to be 2D arrays
y_train_reshaped = y_train.values.reshape(-1, 1)
y_test_reshaped = y_test.values.reshape(-1, 1)

# OneHotEncoder on y_train and y_test data
y_train_encoded = ohe.fit_transform(y_train_reshaped)
y_test_encoded = ohe.transform(y_test_reshaped)

# %% [markdown]
# # Visualizing and Transforming the Data

# %%
# Visualizing training set data
X_train.hist()
plt.tight_layout()
plt.show()
y_train.hist()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The following variables likely need transformation because of their skews: atm_surface_temp, atm_surface_pressure, hydrostatic_pressure_anomaly.

# %%
# Apply atm_surface_temp transformation to X_train (squaring it because of its left skew)
X_train['atm_surface_temp'] = (X_train['atm_surface_temp'])**2
X_train['atm_surface_temp'].hist()

# Apply the same transformation to X_test
X_test['atm_surface_temp'] = (X_test['atm_surface_temp'])**2

# %%
# Apply atm_surface_pressure transformation to X_train (squaring it because of its left skew)
X_train['atm_surface_pressure'] = (X_train['atm_surface_pressure'])**2

#Apply the same transformation to X_test
X_test['atm_surface_pressure'] = (X_test['atm_surface_pressure'])**2

X_train['atm_surface_pressure'].hist()
# Out:
# <Axes: >

# %%
# Apply hydrostatic_pressure_anomaly transformation to X_train (log because of its right skew)
X_train['hydrostatic_pressure_anomaly'] = np.log(X_train['hydrostatic_pressure_anomaly'])
X_train['hydrostatic_pressure_anomaly'].hist()

# Apply the same transformation to X_test
X_test['hydrostatic_pressure_anomaly'] = np.log(X_test['hydrostatic_pressure_anomaly'])

# %%
# Visualization cont.
pd.plotting.scatter_matrix(X_train, figsize=(18, 18))
plt.show()
